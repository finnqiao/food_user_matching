# %%
# mock users
brian = {
    'fname': 'Brian',
    'lname': 'Nguyen',
    'gender': 'Male',
    'age': 4,
    'knowledge': 2,
    'budget': 4,
    'dietary': 1,
    'allergies': {
        'Peanut':0, 
        'Tree Nuts':0, 
        'Milk':1, 
        'Egg':0, 
        'Wheat':0, 
        'Soy':1, 
        'Fish':0, 
        'Shellfish':0, 
        'Meat':0, 
        'Poultry':0
    },
    'location': {
        'neighborhood': 'SOMA',
        'latitude':37.7785189,
        'longitude':-122.4056395
    },
    'curLocation': {
        'latitude':37.771741,
        'longitude':-122.409281
    },
    'cuisines': {
        'African':0, 
        'American':0, 
        'Chinese':1, 
        'Thai':1, 
        'Japanese':1, 
        'Korean':1, 
        'Vietnamese':0, 
        'Indian':0, 
        'Middle Eastern':0, 
        'French':0, 
        'Italian':1, 
        'Mexican':1, 
        'Spanish':0, 
        'Latin American':1, 
        'Mediterranean':0, 
        'Other Asian':1, 
        'Other European':0
    },
    'popularity': 5,
    'rating': 4,
    'proximity': 2,
    'ambience': 1,
    'menu': 2
}

ali = {
    'fname': 'Ali',
    'lname': 'Soyupak',
    'gender': 'Male',
    'age': 1,
    'knowledge': 1,
    'budget': 1,
    'dietary': 3,
    'allergies': {
        'Peanut':0, 
        'Tree Nuts':0, 
        'Milk':1, 
        'Egg':1, 
        'Wheat':0, 
        'Soy':0, 
        'Fish':1, 
        'Shellfish':0, 
        'Meat':1, 
        'Poultry':1
    },
    'location': {
        'neighborhood': 'SOMA',
        'latitude':37.7785189,
        'longitude':-122.4056395
    },
    'curLocation': {
        'latitude':37.771741,
        'longitude':-122.409281
    },
    'cuisines': {
        'African':0, 
        'American':1, 
        'Chinese':0, 
        'Thai':0, 
        'Japanese':0, 
        'Korean':0, 
        'Vietnamese':0, 
        'Indian':0, 
        'Middle Eastern':1, 
        'French':0, 
        'Italian':0, 
        'Mexican':0, 
        'Spanish':0, 
        'Latin American':0, 
        'Mediterranean':0, 
        'Other Asian':0, 
        'Other European':0
    },
    'popularity': 1,
    'rating': 1,
    'proximity': 5,
    'ambience': 4,
    'menu': 4
}

finn = {
    'fname': 'Finn',
    'lname': 'Qiao',
    'gender': 'Male',
    'age': 3,
    'knowledge': 4,
    'budget': 2,
    'dietary': 1,
    'allergies': {
        'Peanut':0, 
        'Tree Nuts':0, 
        'Milk':0, 
        'Egg':0, 
        'Wheat':1, 
        'Soy':0, 
        'Fish':0, 
        'Shellfish':0, 
        'Meat':0, 
        'Poultry':0
    },
    'location': {
        'neighborhood': 'SOMA',
        'latitude':37.7785189,
        'longitude':-122.4056395
    },
    'curLocation': {
        'latitude':37.771741,
        'longitude':-122.409281
    },
    'cuisines': {
        'African':1, 
        'American':0, 
        'Chinese':1, 
        'Thai':1, 
        'Japanese':1, 
        'Korean':0, 
        'Vietnamese':0, 
        'Indian':0, 
        'Middle Eastern':0, 
        'French':1, 
        'Italian':1, 
        'Mexican':1, 
        'Spanish':1, 
        'Latin American':1, 
        'Mediterranean':0, 
        'Other Asian':0, 
        'Other European':1
    },
    'popularity': 2,
    'rating': 4,
    'proximity': 1,
    'ambience': 4,
    'menu': 4
}

# %%
# vendor_template = {
#     id: num,
#     name: vendor-name,
#     desc: [cuisine tags],
#     coords: {
#         lat:,
#         long:
#     },
#     priceRange:
#     type:
# }

# favorites_template = {
#     name
#     date
#     image
#     desc
# }

# %%
topBrian = ['Taqueria Angelicas', 'Noodle in a Haystack: Paitan / Tan Tan', 'ICHIDO Japanese Omakase', 'Mar y Tierra', 'Rockridge Neighborhood Heritage Food Tour', 'Istanbul Modern, Spring (10 course)', 'Spork & Stix', 'Eat Stay Love Lafayette Food Tour', 'United Bites', 'Mayo & Mustard']
topAli = ['Taqueria Angelicas', 'Mar y Tierra', 'Istanbul Modern, Spring (10 course)', 'ICHIDO Japanese Omakase', 'Noodle in a Haystack: Paitan / Tan Tan', 'Rockridge Neighborhood Heritage Food Tour', 'Vegan Date Night: an LGBT community gathering', "Istanbul Modern, Sultans' Brunch, 8-Course", 'Afternoon tea with June', '4-Course Brunch Without A Line']
topFinn = ['Taqueria Angelicas', 'Noodle in a Haystack: Paitan / Tan Tan', 'ICHIDO Japanese Omakase', 'Mar y Tierra', 'Mozzeria', 'Rockridge Neighborhood Heritage Food Tour', 'Little Green Cyclo', 'Eat Stay Love Lafayette Food Tour', 'United Bites', 'Istanbul Modern, Spring (10 course)']
