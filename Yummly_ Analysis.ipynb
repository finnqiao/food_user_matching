# %%
import pandas as pd
import csv
import json
from pprint import pprint

# %%
data = json.load(open('meta00001.json'))
print(data['attributes']['cuisine'])
# Out:
# ['Italian']

# %%
print(data['flavors'])
# Out:
# {}

# %%
print(data['ingredientLines'])
# Out:
# ['2 cups Baby Bella mushrooms, sliced', '2 cups arborio rice', '1 tsp olive oil', '3 tsp butter', '2 shallots, minced', '1 cup white wine', '8 cups fat free chicken stock (or vegetable stock)', 'salt and pepper', 'salt and pepper', '1/2 cup grated parmesan cheese', '4 tbsp chopped parsley']

# %%
pprint(data)
# Out:
# {'attributes': {'course': ['Side Dishes'], 'cuisine': ['Italian']},
#  'attribution': {'html': '<a '
#                          "href='http://www.yummly.com/recipe/Mushroom-risotto-352492'>Mushroom "
#                          'Risotto recipe</a> information powered by <img '
#                          "alt='Yummly' "
#                          "src='http://static.yummly.com/api-logo.png'/>",
#                  'logo': 'http://static.yummly.com/api-logo.png',
#                  'text': 'Mushroom Risotto recipes: information powered by '
#                          'Yummly',
#                  'url': 'http://www.yummly.com/recipe/Mushroom-risotto-352492'},
#  'flavors': {},
#  'id': 'Mushroom-risotto-352492',
#  'images': [{'hostedLargeUrl': 'http://lh3.ggpht.com/RWjPy1Ca7LMIWtS1GQ3T9DcPMsQFWP3bLuR72810CCOoTH3IsoQv17QOgzpDYCEgZxLtvnG8VZBuLKtugBCtOA=s360',
# ...
